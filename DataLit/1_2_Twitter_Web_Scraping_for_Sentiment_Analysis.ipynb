# %%
# !pip install pandas
# !pip install tweepy
# !pip install twython
# !pip install vaderSentiment
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/c2/b0/a3/5c4b4b87b8c9e4d99f1494a0b471f0134a74e5fb33d426d009
# Successfully built twython
# ...

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = 'wcAepFEgjkGgzV8dGhscUMGMK'
consumer_secret = 'bX8uRCNNaDnbgBpSNfY3ImU2ufjdoDP008zBugx8RAV1S01TFk'
access_token = '842760887421321216-AMjjXtxvRTjfzEyAoASU6qZxmISEjI2'
access_token_secret = 'Qsykf3bfSafWZoWlcxEn8NpVXUV1ojcQygTP3OIncCQds'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Artificial Intelligence', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @ITMob: Top 100 Artificial Intelligence and...
# 1  RT @Cognixia: Learn more about how #artificial...
# 2  RT @PredictSense: Artificial Intelligence for ...
# 3  RT @livemint: China is quickly becoming a worl...
# 4  Artificial Intelligence Can Now Create Perfume...
# 5  Using artificial intelligence, speech recognit...
# 6  RT @anandasukarlan: Itu kalau dgn 1 sentuhan m...
# 7  RT @livemint: China is quickly becoming a worl...
# 8  RT @megatronicslab: The key to artificial inte...
# 9  Wow, how about this for a Monday morning read?...
# 2019-07-29 06:16:39

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets                                           polarity
# 0   RT @ITMob: Top 100 Artificial Intelligence and...  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...
# 1   RT @Cognixia: Learn more about how #artificial...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   RT @PredictSense: Artificial Intelligence for ...  {'neg': 0.0, 'neu': 0.763, 'pos': 0.237, 'comp...
# 3   RT @livemint: China is quickly becoming a worl...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4   Artificial Intelligence Can Now Create Perfume...  {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'comp...
# 5   Using artificial intelligence, speech recognit...  {'neg': 0.0, 'neu': 0.613, 'pos': 0.387, 'comp...
# 6   RT @anandasukarlan: Itu kalau dgn 1 sentuhan m...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7   RT @livemint: China is quickly becoming a worl...  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# ...

# %%
data.to_excel('exportao.xlsx')
